# %% [markdown]
# # ◈ Root Finding Calculator
# > **Bisection · Newton-Raphson · Secant · Regula Falsi**
# >
# > Run the cell below to launch the interactive calculator.

# %%
# ── Step 1: Install required libraries ──
# !pip install ipywidgets matplotlib numpy sympy -q

# %%
# ── Step 2: Run the calculator ──
# %run root_finder_jupyter.py
